# %%
import tensorflow as tf
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import pandas as pd

dataset=pd.read_csv("C:\\Users\\mmnri\\Desktop\\jj.csv", na_values= '#DIV/0!' )

df = pd.DataFrame(dataset) 
df = df.apply(lambda x: pd.Series(x.dropna().values)).fillna(' ')

print(df)
# Out:
#           TOINC        TOTEXP  TOTALSAVINGS
# 0       23275.0   8222.916667          64.7
# 1       11987.0  11386.583330           5.0
# 2       13374.0  10284.166670          23.1
# 3       55892.0  27782.750000          50.3
# 4       21665.0  20469.750000           5.5
# ...         ...           ...           ...
# 143557  31890.0  15492.250000          51.4
# 143558  15360.0  12329.333330          19.7
# 143559  75072.0  35645.333330          52.5
# 143560   5438.0   6268.500000         -15.3
# 143561  13939.0  10973.250000          21.3
#
# [143562 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

plt.scatter(df['TOINC'], df['TOTEXP'], color='red')
plt.title('TOTEXP Vs TOINC', fontsize=14)
plt.xlabel('TOINC', fontsize=14)
plt.ylabel('TOTEXP', fontsize=14)
plt.grid(True)
plt.show()

# %%
plt.scatter(df['TOTALSAVINGS'], df['TOTEXP'], color='green')
plt.title('TOTEXP Vs TOTAL SAVINGS', fontsize=14)
plt.xlabel('TOTAL SAVINGS', fontsize=14)
plt.ylabel('TOTEXP', fontsize=14)
plt.show()

# %%
from sklearn import linear_model
import statsmodels.api as sm

x = df[['TOINC','TOTALSAVINGS']]
y = df['TOTEXP']
np.where(np.isnan(x)) 
# with sklearn
regr = linear_model.LinearRegression()
regr.fit(x, y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

# with statsmodels
x = sm.add_constant(x) # adding a constant
 
model = sm.OLS(y, x).fit()
predictions = model.predict([[2,10070,100000]]) 
print(predictions)
# Out:
# Intercept:
#  4079.6956909410783
# Coefficients:
#  [   0.737498  -189.8471913]
# [-18969133.1342728]

# %%
print_model = model.summary()
print(print_model)
# Out:
# 0.776884167826549

# %%
import pickle
pickle.dump(regressor,open('modelrfr.pkl', 'wb'))
